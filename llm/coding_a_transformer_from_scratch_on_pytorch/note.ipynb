# %% [markdown]
# https://www.youtube.com/watch?v=ISNdQcPhsts

# %% [markdown]
# # 架构
# ![image.png](attachment:b366a3ad-e74e-4d87-8837-64cdaf7ec517.png)

# %% [markdown]
# # Input Embedding
# 字符串 -> Token ID -> 向量
#
# ![image.png](attachment:3efef9e7-1119-4eb1-84d2-a01de47f8fa3.png)

# %% [markdown]
# # Positional Encoding
# ![image.png](attachment:08dc4c91-bc46-4dfd-8ef8-2d9646a2e7e9.png)
# ![image.png](attachment:29b673f0-3931-4f56-ac4c-21b0fc503e05.png)

# %% [markdown]
# # Layer Normalization
# ![image.png](attachment:3545274f-f30f-425b-8fec-dff62275731a.png)

# %% [markdown]
# # Feed-Forward Network
# $$
# FFN(x) = max(0, xW_1 + b_1)W_2 + b_2
# $$

# %% [markdown]
# # Multiple Head Attention
# ![image.png](attachment:2518c7c9-6b1e-480a-be61-dd094f025702.png)
